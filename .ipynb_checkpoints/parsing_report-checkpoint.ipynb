# %%
import os, json, imp, re
import package.utils as utils

# %%
log_path = 'cloudmile_log_20181130'
result = utils.loadFileIfExisted(log_path)
lines = re.compile('\[[ \-\d,:]*\]: INFO    : Reading existed ocr response from').split(result)

for idx, line in enumerate(lines):
    if len(line) == 0: continue
    doc_name = ''
    if idx ==1:
        tmp_str = re.compile('(.*)/vision_result.json ...\n').split(line)
#         doc_name = os.path.basename(tmp_str)
        print(tmp_str)

#     line = re.sub(r'\[[ \-\d,:]*\]: ', '', line)
    print(line)
    break
# Out:
# ['', '[2018-11-30 16:48:59,937]: INFO    : Reading existed ocr response from ../../local/src/jpg_root/citi/201612HZML-160004FLCS00172', '[2018-11-30 16:49:00,189]: INFO    : Preparing and organizing ocr response ...\n[2018-11-30 16:49:00,524]: INFO    : Extracting Header and Swift codes for bank citi ...\n[2018-11-30 16:49:01,096]: INFO    : Evaluating letter of credit ...\n[2018-11-30 16:49:01,097]: WARNING : 押匯期限: 不重要，應該與信用狀有效期限相同\n[2018-11-30 16:49:01,099]: WARNING : 保險指示: DAT 需要再從 Document Req 中確認一致性\n[2018-11-30 16:49:01,099]: WARNING : 利息負擔: Missing 39C 預設『客戶負擔』\n[2018-11-30 16:49:01,099]: WARNING : 溢價處理: Missing 42P (目前沒看到過，有待商確)\n[2018-11-30 16:49:01,099]: WARNING : 指定船公司: 在 47A 中 要在與船公司資料庫比對\n[2018-11-30 16:49:01,099]: WARNING : 裝船方式: unable to find movement info in 45A (此欄位不需要看？)\n[2018-11-30 16:49:01,099]: WARNING : 指定代理商: (此欄位不需要看？)\n[2018-11-30 16:49:01,102]: WARNING : 提單: Unable to find document about customs invoice\n[2018-11-30 16:49:01,102]: WARNING : 提單: Unable to find document about importer\n[2018-11-30 16:49:01,102]: WARNING : 提單: Unable to find document about weight list\n[2018-11-30 16:49:01,102]: INFO    : Saving evaluation result in ../../local/src/jpg_root/citi/201612HZML-160004FLCS00172/checklist.json ...\n', '[2018-11-30 16:49:01,126]: INFO    : Reading existed ocr response from ../../local/src/jpg_root/citi/201612SICO-1624014I023908', '[2018-11-30 16:49:01,319]: INFO    : Preparing and organizing ocr response ...\n[2018-11-30 16:49:01,750]: INFO    : Extracting Header and Swift codes for bank citi ...\n[2018-11-30 16:49:02,534]: INFO    : Evaluating letter of credit ...\n[2018-11-30 16:49:02,535]: WARNING : 押匯期限: 不重要，應該與信用狀有效期限相同\n[2018-11-30 16:49:02,535]: WARNING : 交易條件: no term are found in 45A: 50 MT PVC RESIN PR-F (2FCL X 25 MT)\x08DESCRIPTION OF GOODS : PVC RESIN\nAT USD 1,130/MT\nTOTAL AMOUNT USD 56,500.00\nCONTRACT/ORDER NO: 055-I/PO/TU/XII/16 DATED 06 DEC, 2016\nHS NO : 3904\nGOOD AND NEW QUALITY\nPACKING : 25 KG IN PAPER BAG WITH PALLET\nCOUNTRY OF ORIGIN: TAIWAN\nCIF JKT SEA PORT, INDONESIA - INCOTERMS 2010\x08\n[2018-11-30 16:49:02,535]: WARNING : 交易條件: no term are found in 45A: 50 MT PVC RESIN PR-F (2FCL X 25 MT)\x08DESCRIPTION OF GOODS : PVC RESIN\nAT USD 1,130/MT\nTOTAL AMOUNT USD 56,500.00\nCONTRACT/ORDER NO: 055-I/PO/TU/XII/16 DATED 06 DEC, 2016\nHS NO : 3904\nGOOD AND NEW QUALITY\nPACKING : 25 KG IN PAPER BAG WITH PALLET\nCOUNTRY OF ORIGIN: TAIWAN\nCIF JKT SEA PORT, INDONESIA - INCOTERMS 2010\x08\n[2018-11-30 16:49:02,535]: WARNING : 保險指示: 交易條件有誤 無法判斷\n[2018-11-30 16:49:02,535]: WARNING : 利息負擔: Missing 39C 預設『客戶負擔』\n[2018-11-30 16:49:02,535]: WARNING : 溢價處理: Missing 42P (目前沒看到過，有待商確)\n[2018-11-30 16:49:02,535]: WARNING : 出口港: Missing 44E\n[2018-11-30 16:49:02,535]: WARNING : 指定船公司: 在 47A 中 要在與船公司資料庫比對\n[2018-11-30 16:49:02,535]: WARNING : 裝船方式: unable to find movement info in 45A (此欄位不需要看？)\n[2018-11-30 16:49:02,536]: WARNING : 指定代理商: (此欄位不需要看？)\n[2018-11-30 16:49:02,537]: WARNING : 提單: Unable to find document about customs invoice\n[2018-11-30 16:49:02,538]: WARNING : 提單: Unable to find document about consular invoice\n[2018-11-30 16:49:02,538]: WARNING : 提單: Unable to find document about certificate of origin\n[2018-11-30 16:49:02,538]: WARNING : 提單: Unable to find document about certificate of analysis\n[2018-11-30 16:49:02,538]: WARNING : 提單: Unable to find document about inspection certificate\n[2018-11-30 16:49:02,538]: WARNING : 提單: Unable to find document about importer\n[2018-11-30 16:49:02,539]: WARNING : 提單: Unable to find document about weight list\n[2018-11-30 16:49:02,539]: INFO    : Saving evaluation result in ../../local/src/jpg_root/citi/201612SICO-1624014I023908/checklist.json ...\n', '[2018-11-30 16:49:02,563]: INFO    : Reading existed ocr response from ../../local/src/jpg_root/citi/201612SICO-1624014I023908_01', '[2018-11-30 16:49:02,749]: INFO    : Preparing and organizing ocr response ...\n[2018-11-30 16:49:02,996]: INFO    : Extracting Header and Swift code ...
#  ../../local/src/jpg_root/citi/201612HZML-160004FLCS00172/vision_result.json ...
# [2018-11-30 16:49:00,189]: INFO    : Preparing and organizing ocr response ...
# [2018-11-30 16:49:00,524]: INFO    : Extracting Header and Swift codes for bank citi ...
# [2018-11-30 16:49:01,096]: INFO    : Evaluating letter of credit ...
# [2018-11-30 16:49:01,097]: WARNING : 押匯期限: 不重要，應該與信用狀有效期限相同
# [2018-11-30 16:49:01,099]: WARNING : 保險指示: DAT 需要再從 Document Req 中確認一致性
# [2018-11-30 16:49:01,099]: WARNING : 利息負擔: Missing 39C 預設『客戶負擔』
# [2018-11-30 16:49:01,099]: WARNING : 溢價處理: Missing 42P (目前沒看到過，有待商確)
# [2018-11-30 16:49:01,099]: WARNING : 指定船公司: 在 47A 中 要在與船公司資料庫比對
# [2018-11-30 16:49:01,099]: WARNING : 裝船方式: unable to find movement info in 45A (此欄位不需要看？)
# [2018-11-30 16:49:01,099]: WARNING : 指定代理商: (此欄位不需要看？)
# [2018-11-30 16:49:01,102]: WARNING : 提單: Unable to find document about customs invoice
# [2018-11-30 16:49:01,102]: WARNING : 提單: Unable to find document about importer
# [2018-11-30 16:49:01,102]: WARNING : 提單: Unable to find document about weight list
# [2018-11-30 16:49:01,102]: INFO    : Saving evaluation result in ../../local/src/jpg_root/citi/201612HZML-160004FLCS00172/checklist.json ...

# %%
# path = './report.json'
# result = utils.loadFileIfExisted(path)
# count = 0
# for item in result:
#     if not item['status']:
#         count += 1
#         print(item['message'])
#         print('------------------------------------')
# print(count)
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# <ipython-input-2-3dc463b6ac43> in <module>()
#       1 path = './report.json'
# ----> 2 result = utils.loadFileIfExisted(path)
#       3 count = 0
#       4 for item in result:
#       5     if not item['status']:
#
# NameError: name 'utils' is not defined

# %%
from package.logger import cmLog
import imp

# imp.reload(logger)
cmLog(' hello?')
# Out:
# [O] unhandlered message:  hello?
